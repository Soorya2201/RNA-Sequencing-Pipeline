# %%
# Install MiXCR
# !wget https://github.com/milaboratory/mixcr/releases/download/v4.6.1/mixcr-4.6.1.tar.gz
# !tar -xvzf mixcr-4.6.1.tar.gz
# !ln -s /content/mixcr-4.6.1/mixcr /usr/local/bin/mixcr

# Install TRUST4
# !git clone https://github.com/liulab-dfci/TRUST4.git
# !cd TRUST4 && make

# Install ImRep (build from source)
# !git clone https://github.com/mandricigor/imrep.git
# !cd imrep && make

# Other dependencies
# !pip install matplotlib-venn biopython pandas
# Out:
# --2025-09-12 08:20:52--  https://github.com/milaboratory/mixcr/releases/download/v4.6.1/mixcr-4.6.1.tar.gz
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-09-12 08:20:53 ERROR 404: Not Found.
#
# tar (child): mixcr-4.6.1.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now
# Cloning into 'TRUST4'...
# remote: Enumerating objects: 2371, done.
# remote: Counting objects: 100% (493/493), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 2371 (delta 400), reused 395 (delta 386), pack-reused 1878 (from 2)
# Receiving objects: 100% (2371/2371), 1.68 MiB | 7.12 MiB/s, done.
# Resolving deltas: 100% (1527/1527), done.
# g++ -O3 -Wall -g    -c -o main.o main.cpp
# In file included from main.cpp:11:
# ...

# %%
# Install MiXCR directly
# !wget https://github.com/milaboratory/mixcr/releases/download/v4.6.0/mixcr-4.6.0.zip
# !unzip -q mixcr-4.6.0.zip
# !chmod +x mixcr-4.6.0/mixcr

# Test installation
# !./mixcr-4.6.0/mixcr --version

# Download your FASTQ files (your wget commands are correct)
# !wget -O sample1_R1.fastq.gz "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/006/SRR1918236/SRR1918236_1.fastq.gz"
# !wget -O sample1_R2.fastq.gz "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/006/SRR1918236/SRR1918236_2.fastq.gz"
# !wget -O sample2_R1.fastq.gz "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/001/SRR1918241/SRR1918241_1.fastq.gz"
# !wget -O sample2_R2.fastq.gz "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/001/SRR1918241/SRR1918241_2.fastq.gz"

# # Process Sample 1 (using full path to mixcr)
# !./mixcr-4.6.0/mixcr align -s hs -p rna-seq sample1_R1.fastq.gz sample1_R2.fastq.gz sample1.vdjca
# !./mixcr-4.6.0/mixcr assemble sample1.vdjca sample1.clns
# !./mixcr-4.6.0/mixcr exportClones sample1.clns patient_1_mixcr_clonotypes.tsv

# # Process Sample 2 (FIXED the typo: sample_R1_1 → sample2_R1, sample_R2_2 → sample2_R2)
# !./mixcr-4.6.0/mixcr align -s hs -p rna-seq sample2_R1.fastq.gz sample2_R2.fastq.gz sample2.vdjca
# !./mixcr-4.6.0/mixcr assemble sample2.vdjca sample2.clns
# !./mixcr-4.6.0/mixcr exportClones sample2.clns patient_2_mixcr_clonotypes.tsv

# Check your output files
# !ls -la *.tsv
# Out:
# --2025-09-19 21:56:33--  https://github.com/milaboratory/mixcr/releases/download/v4.6.0/mixcr-4.6.0.zip
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget -O sample1_R1.fastq.gz "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/006/SRR1918236/SRR1918236_1.fastq.gz"
# !wget -O sample1_R2.fastq.gz "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/006/SRR1918236/SRR1918236_2.fastq.gz"
# !wget -O sample2_R1.fastq.gz "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/001/SRR1918241/SRR1918241_1.fastq.gz"
# !wget -O sample2_R2.fastq.gz "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/001/SRR1918241/SRR1918241_2.fastq.gz"
# Out:
# --2025-09-12 09:27:51--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/006/SRR1918236/SRR1918236_1.fastq.gz
#            => ‘sample1_R1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR191/006/SRR1918236 ... done.
# ==> SIZE SRR1918236_1.fastq.gz ... 2176434214
# ==> PASV ... done.    ==> RETR SRR1918236_1.fastq.gz ... done.
# Length: 2176434214 (2.0G) (unauthoritative)
#
# SRR1918236_1.fastq. 100%[===================>]   2.03G  15.9MB/s    in 2m 13s
#
# 2025-09-12 09:30:07 (15.6 MB/s) - ‘sample1_R1.fastq.gz’ saved [2176434214]
#
# --2025-09-12 09:30:07--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR191/006/SRR1918236/SRR1918236_2.fastq.gz
#            => ‘sample1_R2.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# ...

# %%
# Install MiXCR directly
# !wget https://github.com/milaboratory/mixcr/releases/download/v4.6.0/mixcr-4.6.0.zip
# !unzip -q mixcr-4.6.0.zip
# !chmod +x mixcr

# Test installation
# !./mixcr --version
# Out:
# --2025-09-12 03:33:40--  https://github.com/milaboratory/mixcr/releases/download/v4.6.0/mixcr-4.6.0.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Replace YOUR_LICENSE_KEY with the actual key you received
# !./mixcr activate-license E-RBXUUOLUGULPQNHYDXSSVCIASXABWWAVCYYLGFTHMSMNQCNZ
# Out:
# Please enter the license:
# E-RBXUUOLUGULPQNHYDXSSVCIASXABWWAVCYYLGFTHMSMNQCNZ
# Checking the license...
# Ok
# License activated successfully.

# %%
# !rm mixcr*

# %%
# !zcat sample1_R1.fastq.gz | head -n 400000 > test_sample_1.fastq
# !zcat sample1_R2.fastq.gz | head -n 400000 > test_sample_2.fastq

# %%
# !./mixcr align -s hs -p rna-seq sample1_R1.fastq.gz sample1_R2.fastq.gz sample1.vdjca
# !./mixcr assemble sample1.vdjca sample1.clns
# !./mixcr exportClones sample1.clns patient_1_mixcr_clonotypes.tsv
# Out:
# Alignment: 0%
# Alignment: 0.5%  ETA: 06:49:55
# Alignment: 1.4%  ETA: 03:45:44
# Alignment: 2.2%  ETA: 03:43:21
# Alignment: 3.1%  ETA: 03:41:54
# Alignment: 4%  ETA: 03:29:02
# ^C
# ^C
# ^C

# %%
# !./mixcr-4.6.0/mixcr align -s hs -p rna-seq sample2_R1.fastq.gz sample2_R2.fastq.gz sample2.vdjca
# !./mixcr-4.6.0/mixcr assemble sample2.vdjca sample2.clns
# !./mixcr-4.6.0/mixcr exportClones sample2.clns patient_2_mixcr_clonotypes.tsv

# %%
# !./TRUST4/trust4 -f ./TRUST4/hg38_bcrtcr.fa -1 sample1_R1.fastq.gz -2 sample1_R2.fastq.gz -o Patient_1_trust4 -t 2
# Out:
# [Fri Sep 12 03:53:29 2025] Start to assemble reads.
# [Fri Sep 12 03:53:32 2025] Read in and count kmers for 400000 reads.
# [Fri Sep 12 03:53:35 2025] Read in and count kmers for 800000 reads.
# [Fri Sep 12 03:53:39 2025] Read in and count kmers for 1200000 reads.
# [Fri Sep 12 03:53:43 2025] Read in and count kmers for 1600000 reads.
# [Fri Sep 12 03:53:48 2025] Read in and count kmers for 2000000 reads.
# [Fri Sep 12 03:53:52 2025] Read in and count kmers for 2400000 reads.
# [Fri Sep 12 03:53:57 2025] Read in and count kmers for 2800000 reads.
# [Fri Sep 12 03:54:02 2025] Read in and count kmers for 3200000 reads.
# [Fri Sep 12 03:54:08 2025] Read in and count kmers for 3600000 reads.
# [Fri Sep 12 03:54:13 2025] Read in and count kmers for 4000000 reads.
# [Fri Sep 12 03:54:18 2025] Read in and count kmers for 4400000 reads.
# [Fri Sep 12 03:54:23 2025] Read in and count kmers for 4800000 reads.
# [Fri Sep 12 03:54:28 2025] Read in and count kmers for 5200000 reads.
# ...

# %%
# !./TRUST4 -f sample2_R1.fastq.gz,sample2_R2.fastq.gz -o patient_2_trust4 -t 2

# %%
# !imrep --reads sample1_R1.fastq.gz sample1_R2.fastq.gz --out patient1_imrep

# %%
# !imrep --reads sample2_R1.fastq.gz sample2_R2.fastq.gz --out patient2_imrep
